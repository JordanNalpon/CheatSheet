# %% [markdown]
# # <font color = yellow> Jordan Cheat Sheet For Data Science </font>

# %% [markdown]
# This is my cheat sheet for python and a dumping ground for any useful code I encounter. Feel free to use these codes and if you have any suggestions or questions please let me know!

# %% [markdown]
# ## <font color = yellow> Index Page </font>

# %% [markdown]
# * [The Basics](#basic)
# * [Imports](#import)
# * [EDA](#EDA)
# * [EDA - Quick Glace](#eda_quickglace)
# * [Null Values](#null)
# * [Modifying the Dataframe](#moddf)
# * [Calculus](#calculus)

# %% [markdown]
# <a name="basic"></a>
# ## <font color = yellow> The Basics </font>

# %% [markdown]
# ### Print

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 'Hello'
y = 'World'
print(x + ' ' + y)
# Out:
# Hello World

# %% [markdown]
# <a name="import"></a>
# ## <font color = yellow> Importing Libraries </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#sklearn imports
import sklearn.linear_model as linear_model
from sklearn import metrics
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.metrics import r2_score, mean_squared_error

# %%
# import json

# sample_info = {}
# sample_info['df_train'] = ('Clean training data set', "--")
# sample_info['df_test'] = ('Clean test data set', "Prepared on 25th Dec")

# with open('./sample_info.json', 'w') as fp:
#     json.dump(sample_info, fp)
    
# with open('./sample_info.json', 'r') as f:
#     sample_info = json.load(f)
    
# for k,v in sample_info.items():
#     print("|" + k + "|" + v + "|")
    
# value =  ("Definition", "Notes")
# value[1]

# %% [markdown]
# ## <font color = yellow> Importing CSV Files </font>

# %% [markdown]
# There are 2 ways of importing CSV files, 1 is by online and the other is reading off your computer. If its reading off your computer, remember to include the dataset when passing the notebook to someone elese.

# %%
df_train = pd.read_csv('data/train.csv')

# %%
#insert code to import CSV file by online

# %% [markdown]
# <a name="eda"></a>
# ## <font color = yellow> EDA </font>

# %% [markdown]
# Exploratory data analysis (EDA) should be the first thing to do with the data. It will tell us how much cleaning is required,

# %% [markdown]
# <a name="eda_quickglace"></a>
# #### <font color = yellow> Quick Glance </font>
#
# Do these to take a quick look at the data frame

# %%
df_train.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
df_train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
df_train.shape
# Out:
# (2051, 81)

# %% [markdown]
# #### <font color=yellow> Column Checker </font>
#
# Custom code to give the relavent details of each column

# %%
# this function will give all the relavent information for each column
def column_checker(column_name):
    print('Column: ' + str(column_name))
    print('Describe: ' + str(df_train[column_name].describe()))
    print('Unique Values: ' + str(df_train[column_name].unique()))
    print(' ')

#
for col in df_train.columns:
    column_checker(col)
# Out:
# Column: Id
# Describe: count    2051.000000
# mean     1474.033642
# std       843.980841
# min         1.000000
# 25%       753.500000
# 50%      1486.000000
# 75%      2198.000000
# max      2930.000000
# Name: Id, dtype: float64
# Unique Values: [109 544 153 ... 916 639  10]
#
# Column: PID
# Describe: count    2.051000e+03
# mean     7.135900e+08
# std      1.886918e+08
# min      5.263011e+08
# 25%      5.284581e+08
# 50%      5.354532e+08
# 75%      9.071801e+08
# max      9.241520e+08
# Name: PID, dtype: float64
# Unique Values: [533352170 531379050 535304180 ... 909253010 535179160 527162130]
#
# Column: MS SubClass
# Describe: count    2051.000000
# mean       57.008776
# std        42.824223
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MS SubClass, dtype: float64
# Unique Values: [ 60  20  50 180 160  70 120 190  85  30  90  80  75  45  40 150]
#
# Column: MS Zoning
# Describe: count     2051
# ...

# %% [markdown]
# #### <font color = yellow> Checking a specific row </font>

# %%
#peeking into what 1342 has
df_train.loc[df_train['Id'] == 1342]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC  Fence  \
# 1327   NaN       IR1          Lvl  ...            0         0     NaN  MnPrv
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 1327          NaN        0       4    2008      ConLD      79000
#
# [1 rows x 81 columns]

# %% [markdown]
# <a name="null"></a>
# ### <font color = yellow> Null Values </font>

# %%
# this tells us how many nulls there are
print('Total number of nulls in train df: ' + str((df_train.isnull().sum()).sum()))
# Out:
# Total number of nulls in train df: 9822

# %%
# this will tall us which columns have null values
df_train.columns[df_train.isna().any()].tolist()
# Out:
# ['Lot Frontage',
#  'Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %% [markdown]
# <a name="moddf"></a>
# ## <font color = yellow> Modifying the dataframe </font>

# %% [markdown]
# #### <font color = yellow> Adding and Removing Elements in Dataframe </font>

# %%
# adding a new empty column
# if you have the values, have the New Column equal to the new values
df_train['New_Column'] = ""

# %%
# removing a column in a dataframe
# axis = 1 is for columns, axis = 0 is for indexes
df_train.drop('New_Column', axis = 1, inplace = True)

# %% [markdown]
# #### <font color = yellow> Renaming Columns </font>

# %%
#adding a new column to be renamed
df_train['Old_Column'] = ""
df_train['Old_Column_2'] = ""

#this will rename the 2 columns
df_train.rename(columns={'Old_Column':'New_Column', 'Old_Column_2':'New_Column_2'}, inplace = True)

#removing the sample columns
df_train.drop({'New_Column','New_Column_2'}, axis = 1 , inplace = True)

# %% [markdown]
# #### <font color= yellow> Merging Dataframe </font>

# %%
# this will combine the two dataframes into a single dataframe

#df_combined = pd.concat([SAT_2017,ACT_2017], axis =1)

# %% [markdown]
# <a name="calculus"></a>
# ## <font color = yellow> Calculus </font>

# %% [markdown]
# #### <font color = yellow> Standard Deviation </font>
#
# <img src="images/StandDev.png">

# %%
#standard deviation code

def stand_dev(data):
    
    # n is the number of values in the column
    n = len(data)
    # mean is the total sum of values in the column divided by n
    mean = (data.sum(axis = 0)) / n
    
    # x is used as a placeholder value to store the sum of ( (current value - mean)**2 / n )
    x = 0
    
    # the value i will loop through all the values in the inputted column and generate a value for dev. The dev value will be added to x which will store the value while the loop repeats with a different i value.
    for i in data:
        dev = (((i - mean)**2)/n)
        x += dev
    
    # the final value of x needs to be squared to get our standard deviation
    return x**0.5

# %%
#Below we will see what is the stand dev for all the columns
sd = {col :stand_dev(df_train[col]) for col in df_train.iloc[: , 1 : :].columns}

sd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ed35a919eb6e> in <module>
#       1 #Below we will see what is the stand dev for all the columns
# ----> 2 sd = {col :stand_dev(df_train[col]) for col in df_train.iloc[: , 1 : :].columns}
#       3
#       4 sd
#
# <ipython-input-28-ed35a919eb6e> in <dictcomp>(.0)
#       1 #Below we will see what is the stand dev for all the columns
# ----> 2 sd = {col :stand_dev(df_train[col]) for col in df_train.iloc[: , 1 : :].columns}
#       3
#       4 sd
#
# <ipython-input-27-6b49640ce22e> in stand_dev(data)
#       6     n = len(data)
#       7     # mean is the total sum of values in the column divided by n
# ----> 8     mean = (data.sum(axis = 0)) / n
#       9
#      10     # x is used as a placeholder value to store the sum of ( (current value - mean)**2 / n )
#
# ...
